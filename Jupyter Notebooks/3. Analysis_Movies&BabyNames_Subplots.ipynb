# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import seaborn as sns
sns.set()
import matplotlib.gridspec as gridspec
from matplotlib import ticker
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)
# %matplotlib inline

# %% [markdown]
# # The Analysis of Data

# %% [markdown]
# ## Visualisation Of Top 3 Movies in 2009, 2011, 2013, 2015 & 2017

# %%
family_movies_2009_top3_read = pd.read_csv('family_movies_2009_top3.csv',index_col=[0])
family_movies_2009_top3_read
# Out:
#                          title  rating  release_year
# 106                         Up     7.9          2009
# 80                    Coraline     7.8          2009
# 187  The Princess and the Frog     7.1          2009

# %%
family_movies_2011_top3_read = pd.read_csv('family_movies_2011_top3.csv',index_col=[0])
family_movies_2011_top3_read
# Out:
#                              title  rating  release_year
# 228       La leyenda de la Llorona     7.7          2011
# 170  Barbie: Princess Charm School     7.4          2011
# 215                    Soul Surfer     7.1          2011

# %%
family_movies_2013_top3_read = pd.read_csv('family_movies_2013_top3.csv',index_col=[0])
family_movies_2013_top3_read
# Out:
#                    title  rating  release_year
# 77                Frozen     7.3          2013
# 172  Monsters University     7.0          2013
# 99            The Croods     6.9          2013

# %%
family_movies_2015_top3_read = pd.read_csv('family_movies_2015_top3.csv',index_col=[0])
family_movies_2015_top3_read
# Out:
#                     title  rating  release_year
# 116            Inside Out     7.9          2015
# 207           Descendants     7.1          2015
# 155  Hotel Transylvania 2     6.8          2015

# %%
family_movies_2017_top3_read = pd.read_csv('family_movies_2017_top3.csv',index_col=[0])
family_movies_2017_top3_read
# Out:
#                title  rating  release_year
# 43              Coco     8.2          2017
# 160           Gifted     8.1          2017
# 269  A Dog's Purpose     7.6          2017

# %%
ranking_2009 = family_movies_2009_top3_read.head(3)
ranking_2011 = family_movies_2011_top3_read.head(3)
ranking_2013 = family_movies_2013_top3_read.head(3)
ranking_2015 = family_movies_2015_top3_read.head(3)
ranking_2017 = family_movies_2017_top3_read.head(3)

# %%
##################################
### set variables for plotting ###
##################################


title09 = ranking_2009['title']
year09 = ranking_2009['release_year']
rate09 = ranking_2009['rating']

title11 = ranking_2011['title']
year11 = ranking_2011['release_year']
rate11 = ranking_2011['rating']

title13 = ranking_2013['title']
year13 = ranking_2013['release_year']
rate13 = ranking_2013['rating']

title15 = ranking_2015['title']
year15 = ranking_2015['release_year']
rate15 = ranking_2015['rating']

title17 = ranking_2017['title']
year17 = ranking_2017['release_year']
rate17 = ranking_2017['rating']

# %%
gs = gridspec.GridSpec(6, 6)

fig, ax = plt.subplots(figsize=(15,20), facecolor=(.955, .955, .955)) 
mpl.pyplot.magma()

ax2a = plt.subplot(gs[1, :2])
ax2b = plt.subplot(gs[1, 2:4])
ax2c = plt.subplot(gs[1, 4:])

ax3a = plt.subplot(gs[2, 1:3])
ax3b = plt.subplot(gs[2, 3:5])


labs=12
tcks=12  

############################
######### Barh Plots #######
############################


bar_1 = ax2a.barh(title09, rate09, height=0.5,align='center',edgecolor="k")
bar_2 = ax2b.barh(title11, rate11,height=0.5,align='center',edgecolor="k")
bar_3 = ax2c.barh(title13, rate13,height=0.5,align='center',edgecolor="k")
bar_4 = ax3a.barh(title15, rate15,height=0.5,align='center',edgecolor="k")
bar_5 = ax3b.barh(title17, rate17,height=0.5,align='center',edgecolor="k")


ax.grid(zorder=0)

def gradientbars(bars):
    grad = np.atleast_2d(np.linspace(0,1,256))
    ax = bars[0].axes
    lim = ax.get_xlim()+ax.get_ylim()
    for bar_1 in bars:
        bar_1.set_zorder(1)
        bar_1.set_facecolor('none')
        x,y = bar_1.get_xy()
        w, h = bar_1.get_width(), bar_1.get_height()
        ax.imshow(grad, extent=[x+w, x, y, y+h], aspect='auto', zorder=1)
    ax.axis(lim)
gradientbars(bar_1)



def gradientbars(bars):
    grad = np.atleast_2d(np.linspace(0,1,256))
    ax = bars[0].axes
    lim = ax.get_xlim()+ax.get_ylim()
    for bar_2 in bars:
        bar_2.set_zorder(1)
        bar_2.set_facecolor('none')
        x,y = bar_2.get_xy()
        w, h = bar_2.get_width(), bar_2.get_height()
        ax.imshow(grad, extent=[x+w, x, y, y+h], aspect='auto', zorder=1)
    ax.axis(lim)
gradientbars(bar_2)



def gradientbars(bars):
    grad = np.atleast_2d(np.linspace(0,1,256))
    ax = bars[0].axes
    lim = ax.get_xlim()+ax.get_ylim()
    for bar_3 in bars:
        bar_3.set_zorder(1)
        bar_3.set_facecolor('none')
        x,y = bar_3.get_xy()
        w, h = bar_3.get_width(), bar_3.get_height()
        ax.imshow(grad, extent=[x+w, x, y, y+h], aspect='auto', zorder=1)
    ax.axis(lim)
gradientbars(bar_3)



def gradientbars(bars):
    grad = np.atleast_2d(np.linspace(0,1,256))
    ax = bars[0].axes
    lim = ax.get_xlim()+ax.get_ylim()
    for bar_4 in bars:
        bar_4.set_zorder(1)
        bar_4.set_facecolor('none')
        x,y = bar_4.get_xy()
        w, h = bar_4.get_width(), bar_4.get_height()
        ax.imshow(grad, extent=[x+w, x, y, y+h], aspect='auto', zorder=1)
    ax.axis(lim)
gradientbars(bar_4)

def gradientbars(bars):
    grad = np.atleast_2d(np.linspace(0,1,256))
    ax = bars[0].axes
    lim = ax.get_xlim()+ax.get_ylim()
    for bar_5 in bars:
        bar_5.set_zorder(1)
        bar_5.set_facecolor('none')
        x,y = bar_5.get_xy()
        w, h = bar_5.get_width(), bar_5.get_height()
        ax.imshow(grad, extent=[x+w, x, y, y+h], aspect='auto', zorder=1)
    ax.axis(lim)
gradientbars(bar_5)



for ax in [ax2a, ax2b,ax2c,ax3a,ax3b]:


    rects = ax.patches
    # Place a label for each bar
    for rect in rects:
        x_value = rect.get_width()
        y_value = rect.get_y() + rect.get_height() 
        space = -30
        ha = 'left'
        if x_value < 0:
            space *= -1
            ha = 'right'
        label = '{:,.1f}'.format(x_value)

        # Create annotation
        ax.annotate(
            label,                      
            (x_value, y_value),     
            xytext=(-30, -20),         
            textcoords='offset points',
            va='center',               
            ha=ha,                     
            color = 'white',
            fontsize=10)   

        
        ax.tick_params(axis='y', which='major', labelsize=7,rotation=0)
        ax.tick_params(axis='x', which='major', labelsize=8)
        
        ax.spines['left'].set_linewidth(1)
        ax.spines['right'].set_linewidth(1)
        ax.spines['top'].set_linewidth(1)
        ax.spines['bottom'].set_linewidth(1)
        
        
        
    



###################################
### titles, axes, ticks & fonts ###
###################################    


ax2a.set_title('2009', fontsize=labs,fontname="Andale Mono",pad=1.2)
ax2b.set_title('2011', fontsize=labs,fontname="Andale Mono",pad=1.2)
ax2c.set_title('2013', fontsize=labs,fontname="Andale Mono",pad=1.2)
ax3a.set_title('2015', fontsize=labs,fontname="Andale Mono",pad=1.2)
ax3b.set_title('2017', fontsize=labs,fontname="Andale Mono",pad=1.2)



ax2a.tick_params(axis="y",direction="inout", pad=0)
ax2b.tick_params(axis="y",direction="inout", pad=0)
ax2c.tick_params(axis="y",direction="inout", pad=0)
ax3a.tick_params(axis="y",direction="inout", pad=0)
ax3b.tick_params(axis="y",direction="inout", pad=0)


plt.tight_layout()
fig.suptitle('Top 3 Most Popular Movies in 2009, 2011, 2013, 2015 and 2017', fontsize=22, fontname="Andale Mono")
fig.tight_layout()
fig.subplots_adjust(top=1.12)
fig.subplots_adjust(hspace=0.4, wspace=1.4)

# %%
fig.savefig('/images/movie_ranks.png', dpi=300)

# %% [markdown]
# ## Read the baby names files

# %%
# Open the newly cleaned csv file

girls_rank = pd.read_csv("girls_rank_clean.csv", index_col=[0])


boys_rank = pd.read_csv("boys_rank_clean.csv", index_col=[0])

# %%
girls_rank.head()
# Out:
#        Name  2020 Rank  2019 Rank  2018 Rank  2017 Rank  2016 Rank  2015 Rank  \
# 5    A'ISHA     5877.0     2458.0     5877.0     4763.0     2757.0     2328.0
# 6   A'ISHAH     5877.0     5877.0     5877.0     5765.0     5877.0     5877.0
# 13   AADHYA      969.0     1252.0     1136.0     1144.0     1057.0     1204.0
# 19    AADYA     2042.0     1497.0     1393.0     1911.0     1241.0     1601.0
# 20  AAEESHA     5877.0     5877.0     5877.0     5765.0     5785.0     5730.0
#
#     2014 Rank  2013 Rank  2012 Rank  ...  2009 Rank  2008 Rank  2007 Rank  \
# 5      2659.0     4050.0     4171.0  ...     3936.0     4524.0     2233.0
# 6      3160.0     5742.0     4171.0  ...     5877.0     4524.0     2895.0
# 13     1155.0     1707.0     1893.0  ...     5877.0     5877.0     5877.0
# 19     1501.0     1253.0     2215.0  ...     5556.0     3860.0     2895.0
# 20     5877.0     5877.0     2717.0  ...     5877.0     5877.0     5877.0
#
# ...

# %%
boys_rank.head()
# Out:
#     Name  2020 Rank  2019 Rank  2018 Rank  2017 Rank  2016 Rank  2015 Rank  \
# 4      A     3848.0     2104.0     3959.0     3996.0     2335.0     2020.0
# 5  A:JAY     2960.0     4813.0     3011.0     1923.0     2335.0     2707.0
# 7  AABAN     3848.0     3937.0     3412.0     2324.0     4810.0     2319.0
# 8  AABID     4608.0     3937.0     3959.0     3996.0     4810.0     3004.0
# 9  AADAM      456.0      327.0      328.0      421.0      326.0      322.0
#
#    2014 Rank  2013 Rank  2012 Rank  ...  2009 Rank  2008 Rank  2007 Rank  \
# 4     2964.0     2660.0     1589.0  ...     4813.0     3158.0     2741.0
# 5     3895.0     2403.0     3416.0  ...     3744.0     3158.0     3095.0
# 7     1281.0     1706.0     1313.0  ...     3227.0     2507.0     4333.0
# 8     4632.0     4813.0     4813.0  ...     4813.0     4813.0     4813.0
# 9      374.0      373.0      434.0  ...      432.0      461.0      470.0
#
# ...

# %% [markdown]
# ## Transpose the rank dataframes

# %%
transpose_girls_rank = girls_rank.transpose()
transpose_girls_rank.head()
# Out:
#             5        6       13     19       20     21      22       23     \
# Name       A'ISHA  A'ISHAH  AADHYA  AADYA  AAEESHA  AAFIA  AAFIYA  AAFIYAH
# 2020 Rank    5877     5877     969   2042     5877   2843    1773     1065
# 2019 Rank    2458     5877    1252   1497     5877   4001    1854     1316
# 2018 Rank    5877     5877    1136   1393     5877   3178    2340     1436
# 2017 Rank    4763     5765    1144   1911     5765   3583    3583     1411
#
#              24      27     ... 21405   21406   21410    21411  21412  21417  \
# Name       AAFREEN  AAHANA  ...  ZURI  ZURIEL  ZUZANA  ZUZANNA  ZUZIA  ZYANA
# 2020 Rank     5877    2042  ...   537    5877    5493      298   5877   5877
# 2019 Rank     5877    2170  ...   980    4686    4001      236   5877   5877
# 2018 Rank     5666    1887  ...  1083    5877    3518      201   5666   2901
# 2017 Rank     4063    2706  ...  1371    4763    5765      189   5877   3583
#
#           21419  21423 21424 21426
# ...

# %%
transpose_boys_rank = boys_rank.transpose()
transpose_boys_rank.head()
# Out:
#           4      5      7      8      9      12      15    23     25     \
# Name          A  A:JAY  AABAN  AABID  AADAM  AADEN  AADHAV  AADI  AADIL
# 2020 Rank  3848   2960   3848   4608    456   4813    4608  3848   1825
# 2019 Rank  2104   4813   3937   3937    327   4813    3937  2266   2266
# 2018 Rank  3959   3011   3412   3959    328   2693    3959  3412   1382
# 2017 Rank  3996   1923   2324   3996    421   3996    4813  2052   2172
#
#            26     ...   16347  16348   16349   16350   16352       16357  \
# Name       AADIT  ...  ZUBEYR  ZUBIN  ZUHAIB  ZUHAIR  ZUHAYR  ZULQARNAIN
# 2020 Rank   4608  ...    4813   4813    4813    2960    3334        2960
# 2019 Rank   2728  ...    4702   4813    4813    3013    4702        2728
# 2018 Rank   4749  ...    4813   3959    4813    3412    3959        2693
# 2017 Rank   3040  ...    4813   4813    3040    2172    2734        4813
#
#             16362 16363 16368 16373
# Name       ZURIEL   ZVI  ZYAN  ZYON
# ...

# %% [markdown]
# Below we have set the column headings to the girls' names and dropped the first row containing the baby names

# %%
new_header = transpose_girls_rank.iloc[0] #grab the first row for the header
new_df_girl = transpose_girls_rank[1:] #take the data less the header row
new_df_girl.columns = new_header #set the header row as the df header

# %%
new_df_girl.head()
# Out:
# Name      A'ISHA A'ISHAH AADHYA AADYA AAEESHA AAFIA AAFIYA AAFIYAH AAFREEN  \
# 2020 Rank   5877    5877    969  2042    5877  2843   1773    1065    5877
# 2019 Rank   2458    5877   1252  1497    5877  4001   1854    1316    5877
# 2018 Rank   5877    5877   1136  1393    5877  3178   2340    1436    5666
# 2017 Rank   4763    5765   1144  1911    5765  3583   3583    1411    4063
# 2016 Rank   2757    5877   1057  1241    5785  3609   1920    2367    5877
#
# Name      AAHANA  ...  ZURI ZURIEL ZUZANA ZUZANNA ZUZIA ZYANA  ZYLA ZYNAH  \
# 2020 Rank   2042  ...   537   5877   5493     298  5877  5877  3117  5877
# 2019 Rank   2170  ...   980   4686   4001     236  5877  5877  3541  5877
# 2018 Rank   1887  ...  1083   5877   3518     201  5666  2901  5666  5877
# 2017 Rank   2706  ...  1371   4763   5765     189  5877  3583  5877  4763
# 2016 Rank   2547  ...  1172   4763   2233     171  4763  2757  5785  5877
#
# Name       ZYRA  ZYVA
# 2020 Rank  2449  2449
# 2019 Rank  4001  3541
# ...

# %%
new_header = transpose_boys_rank.iloc[0] #grab the first row for the header
new_df_boy = transpose_boys_rank[1:] #take the data less the header row
new_df_boy.columns = new_header #set the header row as the df header

# %%
new_df_boy.head()
# Out:
# Name          A A:JAY AABAN AABID AADAM AADEN AADHAV  AADI AADIL AADIT  ...  \
# 2020 Rank  3848  2960  3848  4608   456  4813   4608  3848  1825  4608  ...
# 2019 Rank  2104  4813  3937  3937   327  4813   3937  2266  2266  2728  ...
# 2018 Rank  3959  3011  3412  3959   328  2693   3959  3412  1382  4749  ...
# 2017 Rank  3996  1923  2324  3996   421  3996   4813  2052  2172  3040  ...
# 2016 Rank  2335  2335  4810  4810   326  2556   4023  3079  1704  4810  ...
#
# Name      ZUBEYR ZUBIN ZUHAIB ZUHAIR ZUHAYR ZULQARNAIN ZURIEL   ZVI  ZYAN  \
# 2020 Rank   4813  4813   4813   2960   3334       2960   1431  3848  2404
# 2019 Rank   4702  4813   4813   3013   4702       2728   2488  4813  1869
# 2018 Rank   4813  3959   4813   3412   3959       2693   3412  3011  2445
# 2017 Rank   4813  4813   3040   2172   2734       4813   3996  3996  2512
# 2016 Rank   4813  4813   4023   2556   4813       2556   4810  3478  1804
#
# Name       ZYON
# 2020 Rank  1548
# 2019 Rank  1655
# ...

# %% [markdown]
# To plot graphs, a list including the years 2020 down to 2000 would be useful. Here is a for loop to create such list:

# %%
year_list_2 = []
for i in range(21):
    year = 2020 - i
    year_list_2.append(str(year))
print(year_list_2)
# Out:
# ['2020', '2019', '2018', '2017', '2016', '2015', '2014', '2013', '2012', '2011', '2010', '2009', '2008', '2007', '2006', '2005', '2004', '2003', '2002', '2001', '2000']

# %%
###################################################################
######### Heros Name Variables used for plotting ##################
###################################################################


###################################
######### 2017 Top 3 Movies #######
###################################

# COCO
miguel=new_df_boy['MIGUEL']

# GIFTED
frank=new_df_boy['FRANK']
mary=new_df_girl['MARY']

# A DOGS PURPOSE
ethan=new_df_boy['ETHAN']
hannah=new_df_girl['HANNAH']

maya=new_df_girl['MAYA']
jakob=new_df_boy['JAKOB']



###################################
######### 2015 Top 3 Movies #######
###################################

# Inside Out
riley=new_df_girl['RILEY']
joy=new_df_girl['JOY']

# The Descendants 
# mal=new_df_girl['MAL']
jay=new_df_girl['JAY']
evie=new_df_girl['EVIE']
ben=new_df_boy['BEN']
audrey=new_df_girl['AUDREY']
chad=new_df_boy['CHAD']
# lonnie=new_df_girl['LONNIE']

# Hotal Transylvania 2
mavis=new_df_girl['MAVIS']
dennis=new_df_boy['DENNIS']


###################################
######### 2013 Top 3 Movies #######
###################################
# frozen
elsa=new_df_girl['ELSA']
anna=new_df_girl['ANNA']
olaf=new_df_boy['OLAF']
# kristoff=new_df_boy['KRISTOFF']


# Monsters University 
mike=new_df_boy['MIKE']
james=new_df_boy['JAMES']


# The Croods
# eep=new_df_girl['EEP']
# thunk=new_df_boy['THUNK']
# grug=new_df_boy['GRUG']
guy=new_df_boy['GUY']

###################################
######### 2011 Top 3 Movies #######
###################################

# The Legend of la Llorona
leo=new_df_boy['LEO']
teodora=new_df_girl['TEODORA']

# Barbie
blair=new_df_girl['BLAIR']

# soul Surfer
bethany=new_df_girl['BETHANY']
alana=new_df_girl['ALANA']

###################################
######### 2009 Top 3 Movies #######
###################################

# Up
russell=new_df_boy['RUSSELL']
carl=new_df_boy['CARL']

# coraline
coraline=new_df_girl['CORALINE']


# The Princess and the Frog
tiana=new_df_girl['TIANA']

# %%
######################################################################
######### Villians Name Variables used for plotting ##################
######################################################################

# Coco
ernesto=new_df_boy['ERNESTO']


# A Dogs Purpose
todd=new_df_boy['TODD']


# Hotal Transylvania 2
bela=new_df_girl['BELA']

# frozen
hans=new_df_boy['HANS']

# Monsters University
randall=new_df_boy['RANDALL']


# The Legend of la Llorona
# yoltzin=new_df_boy['YOLTZIN']


# Up
charles=new_df_boy['CHARLES']

# %%
########################
#### second library ####
########################

import matplotlib.pyplot as plt
from matplotlib import ticker
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)
import matplotlib.lines as mlines
import seaborn as sns
sns.set_style("white")
# %matplotlib inline

# %%
fig_size = plt.rcParams["figure.figsize"] = [65, 75]      


fig = plt.figure()


labs=75    
tcks=30  

#########################
######### subplots ######
#########################
   

ax1 = fig.add_subplot(531)
ax2 = fig.add_subplot(532)
ax3 = fig.add_subplot(533)
ax4 = fig.add_subplot(534)
ax5 = fig.add_subplot(535)
ax6 = fig.add_subplot(536)
ax7 = fig.add_subplot(537)
ax8 = fig.add_subplot(538)
ax9 = fig.add_subplot(539)

ax10 = fig.add_subplot(5,3,10)
ax11 = fig.add_subplot(5,3,11)
ax12 = fig.add_subplot(5,3,12)


ax13 = fig.add_subplot(5,3,13)
ax14 = fig.add_subplot(5,3,14)
ax15 = fig.add_subplot(5,3,15)


###################################
######### patches for legend ######
###################################


# hero legend patches
# coco
Miguel = mlines.Line2D([],[],color='red', marker='^', linestyle='None', markersize=25,label='Miguel - Hero')      

# gifted
Mary = mlines.Line2D([],[],color='red', marker='^', linestyle='None', markersize=25,label='Mary - Hero')      
Frank = mlines.Line2D([],[],color='green', marker='^', linestyle='None', markersize=25,label='Frank - Hero')


# a dogs purpose
Ethan = mlines.Line2D([],[],color='deepskyblue', marker='^', linestyle='None', markersize=25,label='Ethan - Hero')
Hannah = mlines.Line2D([],[],color='pink', marker='^', linestyle='None', markersize=25,label='Hannah - Hero')
Maya = mlines.Line2D([],[],color='black', marker='^', linestyle='None', markersize=25,label='Maya - Hero')
Jakob = mlines.Line2D([],[],color='darkred', marker='^', linestyle='None', markersize=25,label='Jakob - Hero')

# inside out
Joy = mlines.Line2D([],[],color='pink', marker='^', linestyle='None', markersize=25,label='Joy - Hero')      
Riley = mlines.Line2D([],[],color='purple', marker='^', linestyle='None', markersize=25,label='Riley - Hero')      


# descendents
Jay = mlines.Line2D([],[],color='red', marker='^', linestyle='None', markersize=25,label='Jay - Hero')      
Evie = mlines.Line2D([],[],color='magenta', marker='^', linestyle='None', markersize=25,label='Evie - Hero')      
Ben = mlines.Line2D([],[],color='deepskyblue', marker='^', linestyle='None', markersize=25,label='Ben - Hero')      
Audrey = mlines.Line2D([],[],color='coral', marker='^', linestyle='None', markersize=25,label='Audrey - Hero')      
Chad = mlines.Line2D([],[],color='green', marker='^', linestyle='None', markersize=25,label='Chad - Hero')      

# Hotel Transylvania 2
Mavis = mlines.Line2D([],[],color='gold', marker='^', linestyle='None', markersize=25,label='Mavis- Hero')      
Dennis = mlines.Line2D([],[],color='cadetblue', marker='^', linestyle='None', markersize=25,label='Dennis - Hero')      
     


# frozen
Elsa = mlines.Line2D([],[],color='hotpink', marker='^', linestyle='None', markersize=25,label='Elsa - Hero')
Anna = mlines.Line2D([],[],color='blueviolet', marker='^', linestyle='None', markersize=25,label='Anna - Hero')
Olaf = mlines.Line2D([],[],color='darkorange', marker='^', linestyle='None', markersize=25,label='Olaf - Hero')

# Monsters University
Mike = mlines.Line2D([],[],color='cyan', marker='^', linestyle='None', markersize=25,label='Mike - Hero')
James = mlines.Line2D([],[],color='darkgreen', marker='^', linestyle='None', markersize=25,label='James - Hero')

# the croods
Guy = mlines.Line2D([],[],color='teal', marker='^', linestyle='None', markersize=25,label='Guy - Hero')



# The Legend of la Llorona
Leo = mlines.Line2D([],[],color='blue', marker='^', linestyle='None', markersize=25,label='Leo - Hero')
Teodora = mlines.Line2D([],[],color='turquoise', marker='^', linestyle='None', markersize=25,label='Teodora - Hero')

# Barbie: Princess Charm School
Blair = mlines.Line2D([],[],color='fuchsia', marker='^', linestyle='None', markersize=25,label='Blair - Hero')


# Soul Surfer
Alana = mlines.Line2D([],[],color='pink', marker='^', linestyle='None', markersize=25,label='Alana - Hero')
Bethany = mlines.Line2D([],[],color='cornflowerblue', marker='^', linestyle='None', markersize=25,label='Bethany - Hero')


# Up
Russell = mlines.Line2D([],[],color='cyan', marker='^', linestyle='None', markersize=25,label='Russell - Hero')
Carl = mlines.Line2D([],[],color='sandybrown', marker='^', linestyle='None', markersize=25,label='Carl - Hero')

# Coraline
Coraline = mlines.Line2D([],[],color='coral', marker='^', linestyle='None', markersize=25,label='Coraline - Hero')

# The Princess and the Frog
Tiana = mlines.Line2D([],[],color='lime', marker='^', linestyle='None', markersize=25,label='Tiana - Hero')




# VILLLIAN LEGEND patches/labels

# coco
Ernesto = mlines.Line2D([],[],color='black', marker='v', linestyle='None', markersize=25,label='Ernesto - Villian')

# A Dog's Purpose
Todd = mlines.Line2D([],[],color='black', marker='v', linestyle='None', markersize=25,label='Todd - Villain')

# hotel translvania 2
Bela = mlines.Line2D([],[],color='black', marker='v', linestyle='None', markersize=25,label='Bela - Villain') 

# frozen
Hans = mlines.Line2D([],[],color='black', marker='v', linestyle='None', markersize=25,label='Hans - Villain')

# Monsters University
Randall = mlines.Line2D([],[],color='black', marker='v', linestyle='None', markersize=25,label='Randall - Villain')

# Monsters University
Charles = mlines.Line2D([],[],color='black', marker='v', linestyle='None', markersize=25,label='Charles - Villain')






#############################
###### Scatter Plots  #######
#############################



# coco
ax1.scatter(year_list_2,miguel, alpha=0.8, s=700,  c='red', marker='^', edgecolors='black',lw=0.5)    
ax1.scatter(year_list_2,ernesto, alpha=0.8, s=700,  c='black', marker='v', edgecolors='black',lw=0.5)    

# gifted
ax2.scatter(year_list_2,frank, alpha=0.8, s=700,  c='green', marker='^', edgecolors='black',lw=0.5)    
ax2.scatter(year_list_2,mary, alpha=0.8, s=700,  c='red', marker='^', edgecolors='black',lw=0.5)    


# A Dog's Purpose
ax3.scatter(year_list_2,ethan, alpha=0.8, s=700,  c='deepskyblue', marker='^', edgecolors='black',lw=0.5)    
ax3.scatter(year_list_2,hannah, alpha=0.8, s=700,  c='pink', marker='^', edgecolors='black',lw=0.5)    
ax3.scatter(year_list_2,todd, alpha=0.8, s=700,  c='black', marker='v', edgecolors='black',lw=0.5)    
ax3.scatter(year_list_2,maya, alpha=0.8, s=700,  c='mediumslateblue', marker='^', edgecolors='black',lw=0.5)    
ax3.scatter(year_list_2,jakob, alpha=0.8, s=700,  c='darkred', marker='^', edgecolors='black',lw=0.5)    

# inside out
ax4.scatter(year_list_2,joy, alpha=0.8, s=700,  c='pink', marker='^', edgecolors='black',lw=0.3)    
ax4.scatter(year_list_2,riley, alpha=0.8, s=700,  c='purple', marker='^', edgecolors='black',lw=0.3)    


# descendents 
ax5.scatter(year_list_2,jay, alpha=0.8, s=700,  c='red', marker='^', edgecolors='black',lw=0.5) 
ax5.scatter(year_list_2,evie, alpha=0.8, s=700,  c='magenta', marker='^', edgecolors='black',lw=0.5)    
ax5.scatter(year_list_2,ben, alpha=0.8, s=700,  c='deepskyblue', marker='^', edgecolors='black',lw=0.5)    
ax5.scatter(year_list_2,audrey, alpha=0.8, s=700,  c='coral', marker='^', edgecolors='black',lw=0.5)    
ax5.scatter(year_list_2,chad, alpha=0.8, s=700,  c='green', marker='^', edgecolors='black',lw=0.5)    
   


 
# Hotel Transylvania 2 
ax6.scatter(year_list_2,mavis, alpha=0.8, s=700,  c='gold', marker='^', edgecolors='black',lw=0.5)    
ax6.scatter(year_list_2,dennis, alpha=0.8, s=700,  c='cadetblue', marker='^', edgecolors='black',lw=0.5)    
ax6.scatter(year_list_2,bela, alpha=0.8, s=700,  c='black', marker='v', edgecolors='black',lw=0.5)    

    
    
    
# frozen
ax7.scatter(year_list_2,elsa, alpha=0.8, s=900,  c='hotpink', marker='^', edgecolors='black',lw=0.5)    
ax7.scatter(year_list_2,anna, alpha=0.8, s=900,  c='blueviolet', marker='^', edgecolors='black',lw=0.5)    
ax7.scatter(year_list_2,olaf, alpha=0.8, s=900,  c='darkorange', marker='^', edgecolors='black',lw=0.5)        
ax7.scatter(year_list_2,hans, alpha=0.8, s=900,  c='black', marker='v', edgecolors='black',lw=0.5)    



# Monsters University
ax8.scatter(year_list_2,mike, alpha=0.8, s=900,  c='cyan', marker='^', edgecolors='black',lw=0.5)    
ax8.scatter(year_list_2,james, alpha=0.8, s=900,  c='darkgreen', marker='^', edgecolors='black',lw=0.5)    
ax8.scatter(year_list_2,randall, alpha=0.8, s=900,  c='black', marker='v', edgecolors='black',lw=0.5)    


# # Croods    
ax9.scatter(year_list_2,guy, alpha=0.8, s=900,  c='teal', marker='^', edgecolors='black',lw=0.5)    



# The Legend of la Llorona
ax10.scatter(year_list_2,leo, alpha=0.8, s=900,  c='blue', marker='^', edgecolors='black',lw=0.5)    
ax10.scatter(year_list_2,teodora, alpha=0.8, s=900,  c='turquoise', marker='^', edgecolors='black',lw=0.5)    
   


# Barbie: Princess Charm School
ax11.scatter(year_list_2,blair, alpha=0.8, s=900,  c='fuchsia', marker='^', edgecolors='black',lw=0.5)    


# Soul Surfer
ax12.scatter(year_list_2,bethany, alpha=0.8, s=900,  c='cornflowerblue', marker='^', edgecolors='black',lw=0.5)    
ax12.scatter(year_list_2,alana, alpha=0.8, s=900,  c='pink', marker='^', edgecolors='black',lw=0.5)    



# Up
ax13.scatter(year_list_2,russell, alpha=0.8, s=900,  c='cyan', marker='^', edgecolors='black',lw=0.5)    
ax13.scatter(year_list_2,carl, alpha=0.8, s=900,  c='orchid', marker='^', edgecolors='black',lw=0.5)    
ax13.scatter(year_list_2,charles, alpha=0.8, s=900,  c='black', marker='v', edgecolors='black',lw=0.5)    


# Coraline
ax14.scatter(year_list_2,coraline, alpha=0.8, s=900,  c='coral', marker='^', edgecolors='black',lw=0.5)    



# The Princess and the Frog
ax15.scatter(year_list_2,tiana, alpha=0.8, s=900,  c='lime', marker='^', edgecolors='black',lw=0.5)    






    
    
    
#  x and y axis label 
ax7.set_ylabel('Rank', fontsize=120,fontname="Andale Mono",labelpad=100)      
ax14.set_xlabel('Year', fontsize=120,fontname="Andale Mono",labelpad=100)      
  
  
#############################
###### Legend Labels  #######
#############################

 
ax1.legend(handles = [Miguel,Ernesto], fontsize=36,borderpad=0.1, labelspacing=0.1,handlelength =0,loc =3,ncol=2)  
ax2.legend(handles = [Frank,Mary],fontsize=36,borderpad=0.1, labelspacing=0.1,handlelength =0,loc = 2)     
ax3.legend(handles = [Ethan,Hannah,Maya,Jakob,Todd],fontsize=36,borderpad=0.1, labelspacing=0.1,handlelength =0,loc = 3,ncol=1)     

ax4.legend(handles = [Joy,Riley],fontsize=36,borderpad=0.1, labelspacing=0.1,handlelength =0,loc = 2)     
ax5.legend(handles = [Jay,Evie,Ben,Audrey,Chad],fontsize=36,borderpad=0.1, labelspacing=0.1,handlelength =0,loc = 3, ncol=3)     
ax6.legend(handles = [Mavis,Dennis,Bela],fontsize=36,borderpad=0.1, labelspacing=0.1,handlelength =0,loc = 2)     

ax7.legend(handles = [Elsa,Anna,Olaf,Hans],fontsize=36,borderpad=0.1, labelspacing=0.1,handlelength =0,loc = 3)     
ax8.legend(handles = [Mike,James,Randall],fontsize=36,borderpad=0.1, labelspacing=0.1,handlelength =0,loc = 4,ncol=3)     
ax9.legend(handles = [Guy],fontsize=36,borderpad=0.1, labelspacing=0.1,handlelength =0,loc = 1)     

ax10.legend(handles = [Leo, Teodora],fontsize=36,borderpad=0.1, labelspacing=0.1,handlelength =0,loc = 4)     
ax11.legend(handles = [Blair],fontsize=36,borderpad=0.1, labelspacing=0.1,handlelength =0,loc = 2)     
ax12.legend(handles = [Alana,Bethany],fontsize=36,borderpad=0.1, labelspacing=0.1,handlelength =0,loc = 3)     

ax13.legend(handles = [Russell,Carl,Charles],fontsize=36,borderpad=0.1, labelspacing=0.1,handlelength =0,loc = 3)     
ax14.legend(handles = [Coraline],fontsize=36,borderpad=0.1, labelspacing=0.1,handlelength =0,loc = 2)     
ax15.legend(handles = [Tiana],fontsize=36,borderpad=0.1, labelspacing=0.1,handlelength =0,loc = 1)     





#####################
###### Titles #######
#####################   
    

# Title
fig.suptitle('The Influence of Movie Heros and Villains on Baby Names', fontsize=90, fontname="Andale Mono")
fig.subplots_adjust(top=0.93)


# subplot titles
ax1.set_title('Coco - 2017', fontsize = 45,fontweight='bold')
ax2.set_title('Gifted - 2017', fontsize = 45,fontweight='bold')
ax3.set_title('A Dogs Purpose - 2017', fontsize = 45,fontweight='bold')

ax4.set_title('Inside Out - 2015', fontsize = 45,fontweight='bold')
ax5.set_title('Descendents - 2015', fontsize = 45,fontweight='bold')
ax6.set_title('Hotel Transylvania 2 - 2015', fontsize = 45,fontweight='bold')

ax7.set_title('Frozen - 2013', fontsize = 45,fontweight='bold')
ax8.set_title('Monsters University - 2013', fontsize = 45,fontweight='bold')
ax9.set_title('The Croods - 2013', fontsize = 45,fontweight='bold')

ax10.set_title('The Legend of la Llorona - 2011', fontsize = 45,fontweight='bold')
ax11.set_title('Barbie: Princess Charm School - 2011', fontsize = 45,fontweight='bold')
ax12.set_title('Soul Surfer - 2011', fontsize = 45,fontweight='bold')

ax13.set_title('Up - 2009', fontsize = 45,fontweight='bold')
ax14.set_title('Coraline - 2009', fontsize = 45,fontweight='bold')
ax15.set_title('The Princess and the Frog - 2009', fontsize = 45,fontweight='bold')
              

    
# individual y-axis limits    
ax1.set_ylim([6000,0])
ax2.set_ylim([400,0])
ax3.set_ylim([1200,0])
ax4.set_ylim([1500,0])
ax5.set_ylim([3500,0])
ax6.set_ylim([6000,0])
ax7.set_ylim([5000,0])
ax8.set_ylim([6000,0])
ax9.set_ylim([1000,0])
ax10.set_ylim([3500,0])
ax11.set_ylim([6000,0])
ax12.set_ylim([300,0])
ax13.set_ylim([1500,0])
ax14.set_ylim([6000,0])
ax15.set_ylim([600,0])






# this controls all the subplots - sets the same parameters 
for ax in [ax1, ax2, ax3, ax4, ax5, ax6, ax7, ax8, ax9,ax10,ax11,ax12,ax13,ax14,ax15]:
    
    ax.set_xlim([20,0])   


    ax.tick_params(labelsize=30)


    M = 5       
    xticks = ticker.MaxNLocator(M) 
    ax.xaxis.set_major_locator(xticks)
    
    N=  7       
    yticks = ticker.MaxNLocator(N)  
    ax.yaxis.set_major_locator(yticks)
    
    ax.xaxis.set_minor_locator(AutoMinorLocator(4))
    ax.yaxis.set_minor_locator(AutoMinorLocator(3))
    
    ax.tick_params('both', length=20, width=3, which='major',direction='in')
    ax.tick_params('both', length=10, width=2, which='minor',direction='in')     


    
    ax.spines['left'].set_linewidth(2)
    ax.spines['right'].set_linewidth(2)
    ax.spines['top'].set_linewidth(2)
    ax.spines['bottom'].set_linewidth(2)


#  subplots lines
for ax in [ax1, ax2, ax3]:
     ax.axvline(3,color='black',lw=3)
    
    
for ax in [ax4, ax5, ax6]:  
    ax.axvline(5,color='black',lw=3)
    
for ax in [ax7, ax8, ax9]:
    ax.axvline(7,color='black',lw=3)
    
    
for ax in [ax10,ax11,ax12]:
     ax.axvline(9,color='black',lw=3)
    
for ax in [ax13,ax14,ax15]:
     ax.axvline(11,color='black',lw=3)
        
        


# subplot annotations lined with axis line
ax1.text(5,1500,'Movie Released',fontsize=20,weight='bold')
ax2.text(5,80,'Movie Released',fontsize=20,weight='bold')
ax3.text(5,200,'Movie Released',fontsize=20,weight='bold')

ax4.text(7,200,'Movie Released',fontsize=20,weight='bold')
ax5.text(7,700,'Movie Released',fontsize=20,weight='bold')
ax6.text(7,1000,'Movie Released',fontsize=20,weight='bold')

ax7.text(8,1400,'Movie Released',fontsize=20,weight='bold')
ax8.text(8,800,'Movie Released',fontsize=20,weight='bold')
ax9.text(8,150,'Movie Released',fontsize=20,weight='bold')

ax10.text(10,500,'Movie Released',fontsize=20,weight='bold')
ax11.text(10,900,'Movie Released',fontsize=20,weight='bold')
ax12.text(10,30,'Movie Released',fontsize=20,weight='bold')

ax13.text(12,190,'Movie Released',fontsize=20,weight='bold')
ax14.text(12,900,'Movie Released',fontsize=20,weight='bold')
ax15.text(13,30,'Movie Released',fontsize=20,weight='bold')
# Out:
# Text(13, 30, 'Movie Released')

# %%
fig.savefig('/images/15_subplot_movie_names.png', dpi=300)
